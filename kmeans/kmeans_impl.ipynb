# %%
import math
import random as rd
import matplotlib.pyplot as plt

# find the euclidean distance between two points
def eucldist(pt1, pt2):
  return math.sqrt((pt1[0]-pt2[0])**2 + (pt1[1]-pt2[1])**2)

# find the centroid of a list of points
def findCentroid(points):
  xavg = sum(x for x, _ in points)/len(points)
  yavg = sum(y for _, y in points)/len(points)
  return (xavg, yavg)

def plotClusters(clusters, centroids):
  plt.xlim(0,40)
  plt.ylim(0,40)
  colors = ['red','blue','green','yellow']
  i = 0
  for cluster in clusters:
    for pt in cluster:
      plt.plot(pt[0],pt[1],marker="o",markeredgecolor=colors[i],markerfacecolor=colors[i])
    plt.plot(centroids[i][0],centroids[i][1],marker="x",markeredgecolor=colors[i],markerfacecolor=colors[i])
    i = i + 1
  plt.show()

# k - the usual, i.e., the number of clusters
# data - 2d datasets organized into tuples (i.e., pairs)
# maxiterations - if the algorithms hasn't stablized, terminate after maxiterations
# return value: the original data reorganized into k clusters
def kmeans2d(k, data, maxiterations=100):
  # pick k random points as our first cluster centroids
  centroids = rd.sample(data, k)
  print(centroids)
  #alternative native python implementation:
  #centroids = []
  #for _ in range(k):
  #  nextrand = rd.randint(0, len(data))
  #  while nextrand in centroids:
  #    nextrand = rd.randint(0, len(data))
  #  centroids.append(nextrand)

  # (re)associate all points with the closest centroid
  for i in range(maxiterations):
    oldcentroids = centroids.copy()  # need to save old centroids to verify whether centroids haven't changed at all
    clusters = [[] for _ in range(k)] # reset the clusters b/c we will be assigning points to closest cluster again using the new centroids
    for pt in data:
      centroid_dists = [eucldist(c, pt) for c in centroids]
      # - cool way to find index of min val - https://stackoverflow.com/a/13301022 
      _, cidx = min((val, idx) for (idx, val) in enumerate(centroid_dists))
      clusters[cidx].append(pt)
    plotClusters(clusters, centroids)
    for idx,cluster in enumerate(clusters):
      centroids[idx] = findCentroid(cluster)    
    print(i, centroids, clusters)
    # compare centroids with oldcentroids to see if we can quit! 
    if (oldcentroids==centroids):
      break
  return clusters

# let's create random 2d data that is essentially two different clusters
xs = [rd.randint(0,40) for _ in range(20)] + [rd.randint(0,40) for _ in range(20)]
ys = [rd.randint(0,40) for _ in range(40)]
data = list(zip(xs,ys))

clusters = kmeans2d(3, data, 20)
print(clusters)
# Out:
# [(14, 3), (40, 30), (29, 13)]
# 0 [(10.384615384615385, 10.076923076923077), (28.0, 32.0), (23.61904761904762, 18.095238095238095)] [[(4, 8), (10, 7), (4, 20), (1, 10), (11, 0), (14, 3), (17, 5), (19, 10), (16, 12), (11, 17), (0, 26), (2, 12), (26, 1)], [(16, 35), (35, 22), (31, 37), (18, 34), (40, 30), (28, 34)], [(23, 21), (22, 22), (14, 29), (40, 10), (15, 27), (33, 8), (4, 37), (30, 2), (6, 33), (38, 13), (19, 18), (19, 20), (18, 29), (21, 30), (27, 25), (22, 12), (29, 13), (32, 5), (19, 18), (40, 5), (25, 3)]]
# 1 [(9.083333333333334, 10.833333333333334), (20.272727272727273, 32.09090909090909), (27.470588235294116, 12.941176470588236)] [[(4, 8), (10, 7), (4, 20), (1, 10), (11, 0), (14, 3), (17, 5), (19, 10), (16, 12), (11, 17), (0, 26), (2, 12)], [(16, 35), (14, 29), (4, 37), (6, 33), (18, 29), (31, 37), (21, 30), (18, 34), (40, 30), (27, 25), (28, 34)], [(23, 21), (35, 22), (22, 22), (40, 10), (15, 27), (33, 8), (30, 2), (38, 13), (19, 18), (19, 20), (22, 12), (29, 13), (32, 5), (19, 18), (40, 5), (25, 3), (26, 1)]]
# 2 [(8.181818181818182, 10.909090909090908), (20.0, 30.923076923076923), (28.0625, 11.3125)] [[(4, 8), (10, 7), (4, 20), (1, 10), (11, 0), (14, 3), (17, 5), (16, 12), (11, 17), (0, 26), (2, 12)], [(16, 35), (22, 22), (14, 29), (15, 27), (4, 37), (6, 33), (18, 29), (31, 37), (21, 30), (18, 34), (40, 30), (27, 25), (28, 34)], [(23, 21), (35, 22), (40, 10), (33, 8), (30, 2), (38, 13), (19, 18), (19, 20), (19, 10), (22, 12), (29, 13), (32, 5), (19, 18), (40, 5), (25, 3), (26, 1)]]
# 3 [(8.181818181818182, 10.909090909090908), (20.133333333333333, 29.533333333333335), (29.071428571428573, 10.0)] [[(4, 8), (10, 7), (4, 20), (1, 10), (11, 0), (14, 3), (17, 5), (16, 12), (11, 17), (0, 26), (2, 12)], [(16, 35), (23, 21), (22, 22), (14, 29), (15, 27), (4, 37), (6, 33), (19, 20), (18, 29), (31, 37), (21, 30), (18, 34), (40, 30), (27, 25), (28, 34)], [(35, 22), (40, 10), (33, 8), (30, 2), (38, 13), (19, 18), (19, 10), (22, 12), (29, 13), (32, 5), (19, 18), (40, 5), (25, 3), (26, 1)]]
# 4 [(8.181818181818182, 10.909090909090908), (20.0, 28.176470588235293), (30.75, 8.666666666666666)] [[(4, 8), (10, 7), (4, 20), (1, 10), (11, 0), (14, 3), (17, 5), (16, 12), (11, 17), (0, 26), (2, 12)], [(16, 35), (23, 21), (22, 22), (14, 29), (15, 27), (4, 37), (6, 33), (19, 18), (19, 20), (18, 29), (31, 37), (21, 30), (18, 34), (40, 30), (27, 25), (28, 34), (19, 18)], [(35, 22), (40, 10), (33, 8), (30, 2), (38, 13), (19, 10), (22, 12), (29, 13), (32, 5), (40, 5), (25, 3), (26, 1)]]
# 5 [(9.083333333333334, 10.833333333333334), (20.0, 28.176470588235293), (31.818181818181817, 8.545454545454545)] [[(4, 8), (10, 7), (4, 20), (1, 10), (11, 0), (14, 3), (17, 5), (19, 10), (16, 12), (11, 17), (0, 26), (2, 12)], [(16, 35), (23, 21), (22, 22), (14, 29), (15, 27), (4, 37), (6, 33), (19, 18), (19, 20), (18, 29), (31, 37), (21, 30), (18, 34), (40, 30), (27, 25), (28, 34), (19, 18)], [(35, 22), (40, 10), (33, 8), (30, 2), (38, 13), (22, 12), (29, 13), (32, 5), (40, 5), (25, 3), (26, 1)]]
# 6 [(9.083333333333334, 10.833333333333334), (20.0, 28.176470588235293), (31.818181818181817, 8.545454545454545)] [[(4, 8), (10, 7), (4, 20), (1, 10), (11, 0), (14, 3), (17, 5), (19, 10), (16, 12), (11, 17), (0, 26), (2, 12)], [(16, 35), (23, 21), (22, 22), (14, 29), (15, 27), (4, 37), (6, 33), (19, 18), (19, 20), (18, 29), (31, 37), (21, 30), (18, 34), (40, 30), (27, 25), (28, 34), (19, 18)], [(35, 22), (40, 10), (33, 8), (30, 2), (38, 13), (22, 12), (29, 13), (32, 5), (40, 5), (25, 3), (26, 1)]]
# [[(4, 8), (10, 7), (4, 20), (1, 10), (11, 0), (14, 3), (17, 5), (19, 10), (16, 12), (11, 17), (0, 26), (2, 12)], [(16, 35), (23, 21), (22, 22), (14, 29), (15, 27), (4, 37), (6, 33), (19, 18), (19, 20), (18, 29), (31, 37), (21, 30), (18, 34), (40, 30), (27, 25), (28, 34), (19, 18)], [(35, 22), (40, 10), (33, 8), (30, 2), (38, 13), (22, 12), (29, 13), (32, 5), (40, 5), (25, 3), (26, 1)]]
